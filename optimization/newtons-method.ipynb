# %% [markdown]
# ![image.png](attachment:d7e3fc76-290a-455f-8084-31d174a9f6eb.png)

# %%
def newton_method(f, f_prime, x0, tol=1e-6, max_iter=100):
    """
    Encontra a raiz de uma função usando o Método de Newton.

    Parâmetros:
        f (function): A função cujo zero queremos encontrar.
        f_prime (function): A derivada de f.
        x0 (float): Estimativa inicial.
        tol (float): Tolerância para o erro (critério de parada).
        max_iter (int): Número máximo de iterações.

    Retorna:
        float: Aproximação da raiz.
        int: Número de iterações realizadas.
    """
    x = x0
    for i in range(max_iter):
        fx = f(x)
        fpx = f_prime(x)
        
        if abs(fpx) < 1e-12:  # Evita divisão por zero
            raise ValueError("Derivada próxima de zero. O método pode não convergir.")
        
        x_new = x - fx / fpx
        
        if abs(x_new - x) < tol:  # Critério de convergência
            return x_new, i + 1
        
        x = x_new

    raise ValueError("Número máximo de iterações atingido. O método não convergiu.")

# %% [markdown]
# ![image.png](attachment:8822d850-008c-46e1-b171-5665a42ff0e8.png)

# %%
# Definir a função e sua derivada
def f(x):
    return x**2 - 2

def f_prime(x):
    return 2 * x

# Parâmetros
x0 = 1.0  # Estimativa inicial
tol = 1e-6  # Tolerância
max_iter = 100  # Número máximo de iterações

# Encontrar a raiz
raiz, iteracoes = newton_method(f, f_prime, x0, tol, max_iter)

print(f"Raiz encontrada: {raiz:.6f} em {iteracoes} iterações")
# Out:
# Raiz encontrada: 1.414214 em 5 iterações

# %%
import numpy as np
import matplotlib.pyplot as plt

# Geração de valores para f(x)
x_vals = np.linspace(0, 2, 500)
y_vals = f(x_vals)

# Plot da função
plt.figure(figsize=(8, 6))
plt.axhline(0, color='black', linewidth=0.8, linestyle="--")
plt.plot(x_vals, y_vals, label="f(x) = x^2 - 2", color="blue")
plt.scatter([raiz], [0], color="red", label=f"Raiz: x = {raiz:.6f}")
plt.title("Método de Newton")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid()
plt.show()

# %%
def newton_optimization(g_prime, g_double_prime, x0, tol=1e-6, max_iter=100):
    """
    Otimiza uma função usando o Método de Newton.

    Parâmetros:
        g_prime (function): A derivada da função g(x).
        g_double_prime (function): A segunda derivada de g(x).
        x0 (float): Estimativa inicial.
        tol (float): Tolerância para o erro (critério de parada).
        max_iter (int): Número máximo de iterações.

    Retorna:
        float: Ponto crítico encontrado (mínimo ou máximo).
        int: Número de iterações realizadas.
    """
    x = x0
    for i in range(max_iter):
        gpx = g_prime(x)
        gppx = g_double_prime(x)

        if abs(gppx) < 1e-12:  # Evita divisão por zero
            raise ValueError("Segunda derivada próxima de zero. O método pode não convergir.")
        
        x_new = x - gpx / gppx

        if abs(x_new - x) < tol:  # Critério de convergência
            return x_new, i + 1
        
        x = x_new

    raise ValueError("Número máximo de iterações atingido. O método não convergiu.")

# %% [markdown]
# ![image.png](attachment:8886d239-3636-4310-9b51-451eab1a4ecd.png)

# %%
# Derivadas da função
def g_prime(x):
    return 2 * x + 2

def g_double_prime(x):
    return 2

# Estimativa inicial
x0 = 0

# Encontrar o ponto crítico
critico, iteracoes = newton_optimization(g_prime, g_double_prime, x0)

print(f"Ponto crítico encontrado: x = {critico:.6f} em {iteracoes} iterações")
# Out:
# Ponto crítico encontrado: x = -1.000000 em 2 iterações
